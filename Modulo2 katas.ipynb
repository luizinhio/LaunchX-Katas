# %% [markdown]
# # Modulo 2 Kata Ambiente virtual

# %% [markdown]
# # Microsoft Windows [Versión 10.0.19044.1503]
# (c) Microsoft Corporation. Todos los derechos reservados.
#
# C:\Users\luis>cd \
#
# C:\>cd Python310
#
# C:\Python310>python -m venv env
#
# C:\Python310>dir
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: 3B20-2CD0
#
#  Directorio de C:\Python310
#
# 11/02/2022  09:39 p. m.    <DIR>          .
# 11/02/2022  09:39 p. m.    <DIR>          ..
# 11/02/2022  05:21 p. m.    <DIR>          DLLs
# 11/02/2022  05:20 p. m.    <DIR>          Doc
# 11/02/2022  09:39 p. m.    <DIR>          env
# 11/02/2022  06:01 p. m.    <DIR>          etc
# 11/02/2022  05:20 p. m.    <DIR>          include
# 11/02/2022  05:20 p. m.    <DIR>          Lib
# 11/02/2022  05:20 p. m.    <DIR>          libs
# 17/01/2022  02:26 p. m.            32,768 LICENSE.txt
# 17/01/2022  02:27 p. m.         1,231,196 NEWS.txt
# 17/01/2022  02:26 p. m.            99,216 python.exe
# 17/01/2022  02:26 p. m.            62,352 python3.dll
# 17/01/2022  02:26 p. m.         4,453,776 python310.dll
# 17/01/2022  02:26 p. m.            97,680 pythonw.exe
# 11/02/2022  06:05 p. m.    <DIR>          Scripts
# 11/02/2022  06:01 p. m.    <DIR>          share
# 11/02/2022  05:21 p. m.    <DIR>          tcl
# 11/02/2022  05:20 p. m.    <DIR>          Tools
# 17/01/2022  02:26 p. m.            97,168 vcruntime140.dll
# 17/01/2022  02:26 p. m.            37,240 vcruntime140_1.dll
#                8 archivos      6,111,396 bytes
#               13 dirs  59,748,749,312 bytes libres
#
#
#
# C:\Python310>cd env
#
# C:\Python310\env>dir
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: 3B20-2CD0
#
#  Directorio de C:\Python310\env
#
# 11/02/2022  09:39 p. m.    <DIR>          .
# 11/02/2022  09:39 p. m.    <DIR>          ..
# 11/02/2022  09:39 p. m.    <DIR>          Include
# 11/02/2022  09:39 p. m.    <DIR>          Lib
# 11/02/2022  09:39 p. m.                77 pyvenv.cfg
# 11/02/2022  09:40 p. m.    <DIR>          Scripts
#                1 archivos             77 bytes
#                5 dirs  59,735,498,752 bytes libres
#
# C:\Python310\env>cd ..
#
# C:\Python310>dir env\Scripts
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: 3B20-2CD0
#
#  Directorio de C:\Python310\env\Scripts
#
# 11/02/2022  09:40 p. m.    <DIR>          .
# 11/02/2022  09:40 p. m.    <DIR>          ..
# 11/02/2022  09:40 p. m.             2,054 activate
# 11/02/2022  09:40 p. m.               983 activate.bat
# 11/02/2022  09:40 p. m.            20,571 Activate.ps1
# 11/02/2022  09:40 p. m.               393 deactivate.bat
# 11/02/2022  09:40 p. m.           106,346 pip.exe
# 11/02/2022  09:40 p. m.           106,346 pip3.10.exe
# 11/02/2022  09:40 p. m.           106,346 pip3.exe
# 11/02/2022  09:39 p. m.           263,056 python.exe
# 11/02/2022  09:39 p. m.           251,792 pythonw.exe
#                9 archivos        857,887 bytes
#                2 dirs  59,729,817,600 bytes libres

# %% [markdown]
# # Activación del ambiente virtual:
#
# C:\Python310>env\Scripts\activate
#
# (env) C:\Python310>pip freeze
#
# (env) C:\Python310>pip install python-dateutil
# Collecting python-dateutil
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting six>=1.5
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, python-dateutil
# Successfully installed python-dateutil-2.8.2 six-1.16.0
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Python310\env\Scripts\python.exe -m pip install --upgrade pip' command.
#
# (env) C:\Python310>pip freeze
# python-dateutil==2.8.2
# six==1.16.0
#
# (env) C:\Python310>deactivate
# C:\Python310>
